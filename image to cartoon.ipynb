# %% [markdown]
# # Convert image into cartoonish image

# %%
import cv2
import numpy as np

# %%
img=cv2.imread("img.jpg")
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [220, 205, 196],
#         [221, 206, 197],
#         [221, 206, 197]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [222, 207, 198],
#         [222, 207, 198],
#         [222, 207, 198]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [224, 209, 200],
#         [224, 209, 200],
#         [224, 209, 200]],
#
#        ...,
#
#        [[230, 226, 191],
#         [235, 231, 196],
#         [239, 236, 205],
#         ...,
#         [247, 240, 213],
#         [248, 241, 214],
#         [248, 241, 214]],
#
#        [[230, 226, 191],
#         [235, 231, 196],
#         [239, 236, 205],
#         ...,
#         [247, 240, 213],
#         [247, 240, 213],
#         [247, 240, 213]],
#
#        [[230, 226, 191],
#         [235, 231, 196],
#         [239, 236, 205],
#         ...,
#         [247, 240, 213],
#         [247, 240, 213],
#         [246, 239, 212]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
grey=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
grey
# Out:
# array([[255, 255, 255, ..., 204, 205, 205],
#        [255, 255, 255, ..., 206, 206, 206],
#        [255, 255, 255, ..., 208, 208, 208],
#        ...,
#        [216, 221, 227, ..., 233, 234, 234],
#        [216, 221, 227, ..., 233, 233, 233],
#        [216, 221, 227, ..., 233, 233, 232]], dtype=uint8)

# %%
plt.imshow(grey)

# %%
grey=cv2.medianBlur(grey,9)
grey
# Out:
# array([[255, 255, 255, ..., 205, 205, 205],
#        [255, 255, 255, ..., 206, 206, 206],
#        [255, 255, 255, ..., 208, 208, 208],
#        ...,
#        [217, 221, 227, ..., 234, 234, 233],
#        [217, 221, 227, ..., 233, 233, 233],
#        [217, 221, 227, ..., 233, 233, 233]], dtype=uint8)

# %%
plt.imshow(grey)

# %%
edges=cv2.adaptiveThreshold(grey,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,13,7)
edges
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [  0, 255, 255, ..., 255, 255, 255],
#        [  0, 255, 255, ..., 255, 255, 255],
#        [  0, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(edges)

# %%
color=cv2.bilateralFilter(img,15,350,555)
color
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [225, 210, 201],
#         [225, 210, 201],
#         [225, 210, 201]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [225, 211, 202],
#         [225, 211, 202],
#         [225, 211, 202]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [226, 211, 202],
#         [226, 211, 202],
#         [226, 211, 202]],
#
#        ...,
#
#        [[241, 237, 209],
#         [241, 237, 209],
#         [241, 238, 211],
#         ...,
#         [248, 241, 215],
#         [248, 241, 215],
#         [248, 241, 215]],
#
#        [[241, 237, 209],
#         [241, 237, 209],
#         [241, 238, 211],
#         ...,
#         [248, 241, 215],
#         [248, 241, 215],
#         [248, 241, 215]],
#
#        [[241, 237, 209],
#         [241, 237, 209],
#         [241, 238, 211],
#         ...,
#         [248, 241, 215],
#         [248, 241, 215],
#         [248, 241, 215]]], dtype=uint8)

# %%
plt.imshow(color)

# %%
cartoon=cv2.bitwise_and(color,color,mask=edges)
cartoon
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [225, 210, 201],
#         [225, 210, 201],
#         [225, 210, 201]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [225, 211, 202],
#         [225, 211, 202],
#         [225, 211, 202]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [226, 211, 202],
#         [226, 211, 202],
#         [226, 211, 202]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [241, 237, 209],
#         [241, 238, 211],
#         ...,
#         [248, 241, 215],
#         [248, 241, 215],
#         [248, 241, 215]],
#
#        [[  0,   0,   0],
#         [241, 237, 209],
#         [241, 238, 211],
#         ...,
#         [248, 241, 215],
#         [248, 241, 215],
#         [248, 241, 215]],
#
#        [[  0,   0,   0],
#         [241, 237, 209],
#         [241, 238, 211],
#         ...,
#         [248, 241, 215],
#         [248, 241, 215],
#         [248, 241, 215]]], dtype=uint8)

# %%
plt.imshow(cartoon)

# %%
sho=cv2.imshow("show",cartoon)
sho
